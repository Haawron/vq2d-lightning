# %%
import json
from pathlib import Path
from tqdm.auto import tqdm

# %%
p_ltt_anns_dir = Path('/data/datasets/ego4d_data/v2/egotracks')
p_anns = [
    p_ltt_anns_dir / 'egotracks_train.json',
    p_ltt_anns_dir / 'egotracks_val.json',
    p_ltt_anns_dir / 'egotracks_challenge_test_unannotated.json',
]
anns = json.load(p_anns[0].open())


p_vq2d_anns_dir = Path('/data/datasets/ego4d_data/v2/annotations')
p_anns_vq2d = [
    p_vq2d_anns_dir / 'vq_train.json',
    p_vq2d_anns_dir / 'vq_val.json',
    p_vq2d_anns_dir / 'vq_test_unannotated.json',
]
p_ann_vq2d = p_anns_vq2d[0]
ann_vq2d = json.load(p_ann_vq2d.open())

# %%
anns['videos'][0]['clips'][0]['annotations'][0]['query_sets']['1'].keys()
# Out:
# dict_keys(['is_valid', 'errors', 'warnings', 'query_frame', 'query_video_frame', 'response_track', 'object_title', 'visual_crop', 'lt_track', 'visual_clip', 'attributes_occurrence', 'query_exported_clip_frame'])

# %%
qset_id = '6'
display(len(anns['videos'][0]['clips'][0]['annotations'][0]['query_sets'][qset_id]['response_track']))
display(anns['videos'][0]['clips'][0]['annotations'][0]['query_sets'][qset_id]['response_track'][0])
display(len(anns['videos'][0]['clips'][0]['annotations'][0]['query_sets'][qset_id]['lt_track']))
display(anns['videos'][0]['clips'][0]['annotations'][0]['query_sets'][qset_id]['lt_track'][0])
# Out:
# 10
# {'frame_number': 593,
#  'x': 1541.75,
#  'y': 394.77,
#  'width': 67.76,
#  'height': 28.76,
#  'rotation': 0,
#  'original_width': 1920,
#  'original_height': 1440,
#  'video_frame_number': 11657,
#  'exported_clip_frame_number': 3558}
# 756
# {'frame_number': 593,
#  'x': 1541.75,
#  'y': 394.77,
#  'width': 67.76,
#  'height': 28.76,
#  'interpolated': False,
#  'video_frame_number': 11657,
#  'exported_clip_frame_number': 3558,
#  'original_width': 1920,
#  'original_height': 1440}

# %%
clip_uids_ltt = []
for ann_video in anns['videos']:
    for ann_clip in ann_video['clips']:
        clip_uids_ltt.append(ann_clip['clip_uid'])
len(clip_uids_ltt), len(set(clip_uids_ltt))
# Out:
# (3546, 3546)

# %%
clip_uids_vq2d = []
for ann_video in ann_vq2d['videos']:
    for ann_clip in ann_video['clips']:
        clip_uids_vq2d.append(ann_clip['clip_uid'])
len(clip_uids_vq2d), len(set(clip_uids_vq2d))
# Out:
# (3538, 3538)

# %%
set(clip_uids_ltt) - set(clip_uids_vq2d), set(clip_uids_vq2d) - set(clip_uids_ltt)
# Out:
# ({'17b73c0a-afda-4944-b2ed-450c9ef97849',
#   '59daca91-5433-48a4-92fc-422b406b551f',
#   '72f95d60-cf26-4821-8d79-4ec72c748031',
#   '74130fd9-3e7b-482a-9627-0f53ac672f57',
#   '87b52dc5-3ac3-47e7-9648-1b719049732f',
#   'b7fc5f98-e5d5-405d-8561-68cbefa75106',
#   'd1419b9b-2944-421b-ba6f-0ddac32d5521',
#   'db211359-c259-4515-9d6c-be521711b6d0'},
#  set())

# %%
sample_ltt = anns['videos'][0]['clips'][0]['annotations'][0]['query_sets']['1']
clip_uid_ltt = anns['videos'][0]['clips'][0]['clip_uid']
for ann_video in ann_vq2d['videos']:
    for ann_clip in ann_video['clips']:
        if ann_clip['clip_uid'] == clip_uid_ltt:
            sample_vq2d = ann_clip
            break

# %%
sample_ltt
# Out:
# {'is_valid': True,
#  'errors': [],
#  'warnings': ['Extra query set annotation'],
#  'query_frame': 517,
#  'query_video_frame': 11201,
#  'response_track': [{'frame_number': 425,
#    'x': 1643.7,
#    'y': 402.24,
#    'width': 276.58,
#    'height': 680.23,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10649,
#    'exported_clip_frame_number': 2550},
#   {'frame_number': 426,
#    'x': 1253.7,
#    'y': 259.0,
#    'width': 648.34,
#    'height': 612.36,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10655,
#    'exported_clip_frame_number': 2556},
#   {'frame_number': 427,
#    'x': 1113.54,
#    'y': 271.53,
#    'width': 679.22,
#    'height': 631.64,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10661,
#    'exported_clip_frame_number': 2562},
#   {'frame_number': 428,
#    'x': 990.02,
# ...

# %%
sample_vq2d['annotations'][1]['query_sets']['1']
# Out:
# {'is_valid': True,
#  'errors': [],
#  'warnings': ['Extra query set annotation'],
#  'query_frame': 517,
#  'query_video_frame': 11201,
#  'response_track': [{'frame_number': 425,
#    'x': 1643.7,
#    'y': 402.24,
#    'width': 276.58,
#    'height': 680.23,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10649},
#   {'frame_number': 426,
#    'x': 1253.7,
#    'y': 259.0,
#    'width': 648.34,
#    'height': 612.36,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10655},
#   {'frame_number': 427,
#    'x': 1113.54,
#    'y': 271.53,
#    'width': 679.22,
#    'height': 631.64,
#    'rotation': 0,
#    'original_width': 1920,
#    'original_height': 1440,
#    'video_frame_number': 10661},
#   {'frame_number': 428,
#    'x': 990.02,
#    'y': 336.55,
#    'width': 733.87,
#    'height': 681.5,
#    'rotation': 0,
#    'original_width': 1920,
# ...

# %%
REPORTED_INVALID_CLIP_UIDS = {
    # vq2d
    'b6061527-3ae2-46b4-b050-15eddc1967bb',

    # egotracks
    # https://discuss.ego4d-data.org/t/egotracks-dataset-download-failure/218/28?page=2
    '59daca91-5433-48a4-92fc-422b406b551f',
    'db211359-c259-4515-9d6c-be521711b6d0',
    '87b52dc5-3ac3-47e7-9648-1b719049732f',
    'b7fc5f98-e5d5-405d-8561-68cbefa75106'
}


def generate_flat_annotations_ego4d(p_official_ann: Path):
    """
    Usage
    -----
    
    Basic usage:
    
        from ltvu.preprocess import generate_flat_annotations_ego4d
        p_official_ann = Path('SOMEPATH/vq_val.json')
        flat_anns = generate_flat_annotations_ego4d(p_official_ann)
    """

    def polish_bbox_dict_keys(bbox: dict):
        key_map = {
            'frame_number': 'fno',
            'x': 'x', 'y': 'y', 'width': 'w', 'height': 'h',
            'original_width': None, 'original_height': None}
        return {key_map[k]: v for k, v in bbox.items() if key_map.get(k) is not None}

    all_anns = json.load(p_official_ann.open())
    is_annotated = 'unannotated' not in p_official_ann.stem
    flat_anns = []
    count_invalids = 0
    for ann_video in all_anns['videos']:
        video_uid = ann_video['video_uid']
        if len(ann_video['clips']) == 0:
            flat_anns.append({'video_uid': video_uid})
            continue
        for ann_clip in ann_video['clips']:
            clip_uid = ann_clip['clip_uid']
            if clip_uid is None or clip_uid in REPORTED_INVALID_CLIP_UIDS:
                continue
            clip_duration = ann_clip['video_end_sec'] - ann_clip['video_start_sec']
            clip_fps = ann_clip['clip_fps']
            for ann_annots in ann_clip['annotations']:
                annotation_uid = ann_annots.get('annotation_uid')
                for qset_id, qset in ann_annots['query_sets'].items():
                    if 'is_valid' in qset and not qset['is_valid']:
                        count_invalids += 1
                        continue

                    oh, ow = qset['visual_crop']['original_height'], qset['visual_crop']['original_width']
                    sample = {
                        'video_uid': video_uid,
                        'clip_uid': clip_uid,
                        'annotation_uid': annotation_uid,
                        'query_set': qset_id,
                        'clip_fps': clip_fps,
                        'clip_duration': clip_duration,
                        'original_width': ow,
                        'original_height': oh,
                        'query_frame': qset.get('query_frame', 1000000),
                        'object_title': qset['object_title'],
                        'visual_crop': polish_bbox_dict_keys(qset['visual_crop']),
                    }

                    if sample['query_frame'] == 1000000:  # egotracks test
                        del sample['query_frame']

                    if annotation_uid is not None:  # vq2d train/val
                        sample['uuid_vq2d'] = f'{annotation_uid}_{qset_id}'

                    sample['uuid_ltt'] = f'{clip_uid}_{qset_id}_{qset["object_title"]}'

                    if is_annotated:
                        rt = [polish_bbox_dict_keys(bbox) for bbox in qset['response_track']]
                        sample.update({
                            'response_track_valid_range': [rt[0]['fno'], rt[-1]['fno']],
                            'response_track': rt,
                        })

                        if 'lt_track' in qset:
                            ltt = [polish_bbox_dict_keys(bbox) for bbox in qset['lt_track']]
                            sample['lt_track'] = ltt

                        if 'visual_clip' in qset:
                            vcl = [polish_bbox_dict_keys(bbox) for bbox in qset['visual_clip']]
                            sample.update({
                                'visual_clip_valid_range': [vcl[0]['fno'], vcl[-1]['fno']],
                                'visual_clip': vcl,
                            })
                            assert len(vcl) == vcl[-1]['fno'] - vcl[0]['fno'] + 1
                    flat_anns.append(sample)
    return flat_anns


display(len(generate_flat_annotations_ego4d(p_anns[0])))
display(len(generate_flat_annotations_ego4d(p_anns[1])))
display(len(generate_flat_annotations_ego4d(p_anns[2])))
display(len(generate_flat_annotations_ego4d(p_anns_vq2d[0])))
display(len(generate_flat_annotations_ego4d(p_anns_vq2d[1])))
display(len(generate_flat_annotations_ego4d(p_anns_vq2d[2])))
# Out:
# 13626
# 4513
# 245
# 13614
# 4512
# 4467

# %%
submission = json.load(open('/data/gunsbrother/repos/episodic-memory/EgoTracks/res/test_challenge_set_small_v1_5FPS_multi_gpu_test/eval/EGO4DLTTracking/forward_backward_from_vcrop/STARK/submission.json'))
len(submission.keys())
# Out:
# 250

# %%
sorted(list(submission.keys()))[:100]
# Out:
# ['0d393f9f-0c1e-4f58-b29b-040fe20da32b_1_mouse',
#  '0d393f9f-0c1e-4f58-b29b-040fe20da32b_2_television',
#  '0d393f9f-0c1e-4f58-b29b-040fe20da32b_3_sign post',
#  '143024d5-b356-485e-b5d6-3169aeff4ebe_1_seat',
#  '143024d5-b356-485e-b5d6-3169aeff4ebe_2_tent bag',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_1_bucket',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_2_polythene bag',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_3_stair box',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_4_pocket knife',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_5_gardening shear',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_6_container',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_1_spanner',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_2_cup',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_3_tumbler',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_1_car',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_2_seat',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_3_tent bag',
#  '35cd0847-7086-4078-84d5-9e29c78ec155_1_bucket',
# ...

# %%
sorted([ann.get('uuid_ltt', '') for ann in generate_flat_annotations_ego4d(p_anns[2])])[:100]
# Out:
# ['',
#  '0d393f9f-0c1e-4f58-b29b-040fe20da32b_1_mouse',
#  '0d393f9f-0c1e-4f58-b29b-040fe20da32b_2_television',
#  '0d393f9f-0c1e-4f58-b29b-040fe20da32b_3_sign post',
#  '143024d5-b356-485e-b5d6-3169aeff4ebe_1_seat',
#  '143024d5-b356-485e-b5d6-3169aeff4ebe_2_tent bag',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_1_bucket',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_2_polythene bag',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_3_stair box',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_4_pocket knife',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_5_gardening shear',
#  '2abe71a5-f0be-4994-8653-ab9393abd478_6_container',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_1_spanner',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_2_cup',
#  '2e82610a-f871-4f07-a4b1-0065087bf57b_3_tumbler',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_1_car',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_2_seat',
#  '3127bf0f-4310-4a2f-be56-30dc777f79aa_3_tent bag',
#  '35cd0847-7086-4078-84d5-9e29c78ec155_1_bucket',
# ...

# %%
set(list(submission.keys())) - set([ann.get('uuid_ltt', '') for ann in generate_flat_annotations_ego4d(p_anns[2])])
# Out:
# {'622c1b29-76c6-4845-95df-7e54792687d4_1_microwave',
#  '622c1b29-76c6-4845-95df-7e54792687d4_2_television',
#  '622c1b29-76c6-4845-95df-7e54792687d4_3_container',
#  '622c1b29-76c6-4845-95df-7e54792687d4_4_chopping stick',
#  '622c1b29-76c6-4845-95df-7e54792687d4_5_knife',
#  '622c1b29-76c6-4845-95df-7e54792687d4_6_scissors'}

# %%
import math

sample_bbox = [
    # xywh + score
    1082.2,
    112.6,
    378.1,
    730.2,
    0.01
]

sample_submission = {}
for ann in generate_flat_annotations_ego4d(p_anns[2]):
    if 'uuid_ltt' not in ann:
        continue

    sample_submission[ann['uuid_ltt']] = {}

    for fno in range(0, math.ceil(30*ann['clip_duration']), 6):
        if any(clip_uid in ann['clip_uid'] for clip_uid in ('f532b434', 'b2d890a1', 'fa2d871e')):
            fno -= 1
        if 'cb45277e' in ann['clip_uid']:
            fno += 1
        sample_submission[ann['uuid_ltt']][fno] = sample_bbox

# for k in {
#     '622c1b29-76c6-4845-95df-7e54792687d4_1_microwave',
#     '622c1b29-76c6-4845-95df-7e54792687d4_2_television',
#     '622c1b29-76c6-4845-95df-7e54792687d4_3_container',
#     '622c1b29-76c6-4845-95df-7e54792687d4_4_chopping stick',
#     '622c1b29-76c6-4845-95df-7e54792687d4_5_knife',
#     '622c1b29-76c6-4845-95df-7e54792687d4_6_scissors'
# }:
#     sample_submission[k] = {}

#     for fno in range(0, 9000, 6):
#         sample_submission[k][fno] = sample_bbox

json.dump(sample_submission, open('./sample_submission.json', 'w'), indent=1)

# %%
set(list(submission.keys())) - set(sample_submission.keys())
# Out:
# set()

# %%
len({f'{k}_{fno}' for k in submission for fno in submission[k]})
# Out:
# 444423

# %%
sorted(list({f'{k}_{fno}' for k in submission for fno in submission[k]} - {f'{k}_{fno}' for k in sample_submission for fno in sample_submission[k]}))
# Out:
# []

# %% [markdown]
# # 결론
#
# ## `'622c1b29'` 없어도 됨
#
# ## 에러 난 클립 몇 개만 손 봐주면 됨

# %% [markdown]
# # 그럼 intermediate results 테스트 폼으로 만들기

# %%
# %cd /data/gunsbrother/repos/vq2d-lightning/

import math
import json
from pathlib import Path
import torch
from ltvu.preprocess import generate_flat_annotations_egotracks
# Out:
# /home/gunsbrother/.local/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /data/gunsbrother/repos/vq2d-lightning

# %%
p_preds_pt = Path('outputs/debug/2024-11-07/139821/egotracks/test_intermediate_predictions.pt')
preds = torch.load(p_preds_pt, weights_only=True)
preds[list(preds.keys())[0]]
# Out:
# {'ret_bboxes': tensor([[   0.0000,  946.1116,  189.5355, 1080.0000],
#          [1054.3016,  717.4481, 1440.0000,  999.7926],
#          [ 645.9616,  745.2776,  708.9231,  807.3522],
#          ...,
#          [ 882.6357,  959.6737,  954.6669, 1052.1292],
#          [ 886.0250,  961.9554,  957.5272, 1056.8684],
#          [ 885.3312,  946.8566,  955.9724, 1025.2245]]),
#  'ret_scores': tensor([-3.0042, -3.0682, -2.6269,  ..., -1.7784, -1.9323, -1.7848])}

# %%
list(preds.keys())[0]
# Out:
# '0d393f9f-0c1e-4f58-b29b-040fe20da32b_1_mouse'

# %%
preds[list(preds.keys())[5]]['ret_scores'].sigmoid()
# Out:
# tensor([0.4564, 0.5262, 0.6343,  ..., 0.3074, 0.1940, 0.2275])

# %%
anns = generate_flat_annotations_egotracks('/data/datasets/ego4d_data/v2/egotracks/egotracks_challenge_test_unannotated.json')

# %%
submission = {}
for ann in anns:
    if 'uuid_ltt' not in ann:
        continue

    submission[ann['uuid_ltt']] = {}

    for fnol in range(0, math.ceil(30*ann['clip_duration']), 6):
        fnor = fnol // 6
        if any(clip_uid in ann['clip_uid'] for clip_uid in ('f532b434', 'b2d890a1', 'fa2d871e')):
            fnol -= 1
        elif 'cb45277e' in ann['clip_uid']:
            fnol += 1

        clip_len = int(ann['clip_fps'] * ann['clip_duration'])

        uuid_ltt = ann['uuid_ltt']
        pred = preds[uuid_ltt]
        bboxes = pred['ret_bboxes']
        scores = pred['ret_scores'].sigmoid()
        if fnor == len(bboxes):
            fnor -= 1
        score = scores[fnor].item()
        submission[uuid_ltt][fnol] = bboxes[fnor].tolist() + [score]

json.dump(submission, p_preds_pt.with_name('test_submission.json').open('w'), indent=1)

# %% [markdown]
# # 평가하기
