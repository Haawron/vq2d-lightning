# %%
import json
from pathlib import Path
from tqdm import tqdm

# %%
REPORTED_INVALID_CLIP_UIDS = {
    'b6061527-3ae2-46b4-b050-15eddc1967bb',  # vq2d
}

def generate_flat_annotations_egotracks(all_anns):

    def polish_bbox_dict_keys(bbox: dict):
        key_map = {
            'frame_number': 'fno',
            'x': 'x', 'y': 'y', 'width': 'w', 'height': 'h',
            'original_width': None, 'original_height': None}
        return {key_map[k]: v for k, v in bbox.items() if key_map.get(k) is not None}

    flat_anns = []
    count_invalids = 0
    for ann_video in all_anns['videos']:
        video_uid = ann_video['video_uid']
        for ann_clip in ann_video['clips']:
            clip_uid = ann_clip['clip_uid']
            if clip_uid is None or clip_uid in REPORTED_INVALID_CLIP_UIDS:
                continue
            clip_duration = ann_clip['video_end_sec'] - ann_clip['video_start_sec']
            clip_fps = ann_clip['clip_fps']
            for ann_annots in ann_clip['annotations']:
                for qset_id, qset in ann_annots['query_sets'].items():
                    annotation_uid = f'{clip_uid}_{qset_id}'
                    if not (qset['is_valid'] and 'lt_track' in list(qset.keys())):
                        count_invalids += 1
                        continue
                    if not 'original_height' in list(qset['lt_track'][0].keys()) or not 'original_width' in list(qset['lt_track'][0].keys()):
                        oh, ow = qset['visual_crop']['original_height'], qset['visual_crop']['original_width']
                    else:
                        oh, ow = qset['lt_track'][0]['original_height'], qset['lt_track'][0]['original_width']
                    rt = [polish_bbox_dict_keys(bbox) for bbox in qset['lt_track']]
                    sample = {
                        'video_uid': video_uid,
                        'clip_uid': clip_uid,
                        'annotation_uid': annotation_uid,
                        'query_set': qset_id,
                        'clip_fps': clip_fps,
                        'clip_duration': clip_duration,
                        'original_width': ow,
                        'original_height': oh,
                        'query_frame': qset['query_frame'],
                        'object_title': qset['object_title'],
                        'visual_crop': polish_bbox_dict_keys(qset['visual_crop']),
                        'lt_track_valid_range': [rt[0]['fno'], rt[-1]['fno']],
                        'lt_track': rt,
                    }
                    flat_anns.append(sample)
    return flat_anns

# %%
p_track_ann = Path(f"/data/datasets/ego4d_data/v2/egotracks/egotracks_val.json")
track_anns = json.load(p_track_ann.open())
track_anns['videos'][0]
# Out:
# {'video_uid': '20400762-1e47-462d-a7d1-64a1b162b1f9',
#  'split': 'val',
#  'clips': [{'clip_uid': '307c3ec6-886e-4d25-9ef7-7bea3cf7a243',
#    'video_start_sec': 450.0,
#    'video_end_sec': 930.0,
#    'video_start_frame': 13500,
#    'video_end_frame': 27900,
#    'clip_start_sec': 0,
#    'clip_end_sec': 480.0,
#    'clip_start_frame': 0,
#    'clip_end_frame': 14400,
#    'clip_fps': 5.0,
#    'annotation_complete': True,
#    'source_clip_uid': '2751261c-c3c1-463e-8932-b92889b705d5',
#    'annotations': [{'query_sets': {'1': {'is_valid': True,
#        'errors': [],
#        'warnings': ['Extra query set annotation'],
#        'query_frame': 1306,
#        'query_video_frame': 21336,
#        'response_track': [{'frame_number': 1191,
#          'x': 89.28,
#          'y': 0.42,
#          'width': 153.26,
#          'height': 108.25,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20646,
#          'exported_clip_frame_number': 7146},
#         {'frame_number': 1192,
#          'x': 302.14,
#          'y': 7.72,
#          'width': 166.64,
#          'height': 120.42,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20652,
#          'exported_clip_frame_number': 7152},
#         {'frame_number': 1193,
#          'x': 406.74,
#          'y': 47.86,
#          'width': 177.58,
#          'height': 131.36,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20658,
#          'exported_clip_frame_number': 7158},
#         {'frame_number': 1194,
#          'x': 417.69,
#          'y': 109.89,
#          'width': 197.04,
#          'height': 141.09,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20664,
#          'exported_clip_frame_number': 7164},
#         {'frame_number': 1195,
#          'x': 388.5,
#          'y': 109.89,
#          'width': 226.23,
#          'height': 156.9,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20670,
#          'exported_clip_frame_number': 7170},
#         {'frame_number': 1196,
#          'x': 412.82,
#          'y': 167.06,
#          'width': 235.97,
#          'height': 149.61,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20676,
#          'exported_clip_frame_number': 7176},
#         {'frame_number': 1197,
#          'x': 442.31,
#          'y': 173.14,
#          'width': 232.09,
#          'height': 147.64,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20682,
#          'exported_clip_frame_number': 7182},
#         {'frame_number': 1198,
#          'x': 525.2,
#          'y': 160.98,
#          'width': 223.8,
#          'height': 140.46,
#          'rotation': 0,
#          'original_width': 1920,
#          'original_height': 1080,
#          'video_frame_number': 20688,
#          'exported_clip_frame_number': 7188}],
#        'object_title': 'blowtorch',
#        'visual_crop': {'frame_number': 454,
#         'x': 347.84,
#         'y': 266.99,
#         'width': 228.51,
#         'height': 156.35,
#         'rotation': 0,
#         'original_width': 1920,
#         'original_height': 1080,
#         'video_frame_number': 16224,
#         'exported_clip_frame_number': 2724},
#        'lt_track': [{'frame_number': 1191,
#          'x': 89.28,
#          'y': 0.42,
#          'width': 153.26,
#          'height': 108.25,
#          'video_frame_number': 20646,
#          'exported_clip_frame_number': 7146,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1192,
#          'x': 302.14,
#          'y': 7.72,
#          'width': 166.64,
#          'height': 120.42,
#          'video_frame_number': 20652,
#          'exported_clip_frame_number': 7152,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1193,
#          'x': 406.74,
#          'y': 47.86,
#          'width': 177.58,
#          'height': 131.36,
#          'video_frame_number': 20658,
#          'exported_clip_frame_number': 7158,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1194,
#          'x': 417.69,
#          'y': 109.89,
#          'width': 197.04,
#          'height': 141.09,
#          'video_frame_number': 20664,
#          'exported_clip_frame_number': 7164,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1195,
#          'x': 388.5,
#          'y': 109.89,
#          'width': 226.23,
#          'height': 156.9,
#          'video_frame_number': 20670,
#          'exported_clip_frame_number': 7170,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1196,
#          'x': 412.82,
#          'y': 167.06,
#          'width': 235.97,
#          'height': 149.61,
#          'video_frame_number': 20676,
#          'exported_clip_frame_number': 7176,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1197,
#          'x': 442.31,
#          'y': 173.14,
#          'width': 232.09,
#          'height': 147.64,
#          'video_frame_number': 20682,
#          'exported_clip_frame_number': 7182,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1198,
#          'x': 525.2,
#          'y': 160.98,
#          'width': 223.8,
#          'height': 140.46,
#          'video_frame_number': 20688,
#          'exported_clip_frame_number': 7188,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 187,
#          'x': 1720.45,
#          'y': 751.89,
#          'width': 92.34,
#          'height': 150.74,
#          'video_frame_number': 14622,
#          'exported_clip_frame_number': 1122,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 188,
#          'x': 1533.79,
#          'y': 491.66,
#          'width': 133.75,
#          'height': 79.84,
#          'video_frame_number': 14628,
#          'exported_clip_frame_number': 1128,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 189,
#          'x': 1452.33,
#          'y': 390.3,
#          'width': 142.33,
#          'height': 71.94,
#          'video_frame_number': 14634,
#          'exported_clip_frame_number': 1134,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 190,
#          'x': 1485.68,
#          'y': 395.81,
#          'width': 153.11,
#          'height': 77.31,
#          'video_frame_number': 14640,
#          'exported_clip_frame_number': 1140,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 191,
#          'x': 1667.89,
#          'y': 449.1,
#          'width': 194.54,
#          'height': 59.04,
#          'video_frame_number': 14646,
#          'exported_clip_frame_number': 1146,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 195,
#          'x': 1458.92,
#          'y': 808.85,
#          'width': 155.4,
#          'height': 200.18,
#          'video_frame_number': 14670,
#          'exported_clip_frame_number': 1170,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 196,
#          'x': 1212.47,
#          'y': 679.45,
#          'width': 85.4,
#          'height': 57.38,
#          'video_frame_number': 14676,
#          'exported_clip_frame_number': 1176,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 197,
#          'x': 1117.56,
#          'y': 636.01,
#          'width': 84.22,
#          'height': 54.79,
#          'video_frame_number': 14682,
#          'exported_clip_frame_number': 1182,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 198,
#          'x': 1080.37,
#          'y': 639.26,
#          'width': 87.32,
#          'height': 55.21,
#          'video_frame_number': 14688,
#          'exported_clip_frame_number': 1188,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 199,
#          'x': 1083.75,
#          'y': 657.29,
#          'width': 77.45,
#          'height': 41.09,
#          'video_frame_number': 14694,
#          'exported_clip_frame_number': 1194,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 200,
#          'x': 1099.83,
#          'y': 651.41,
#          'width': 113.93,
#          'height': 232.57,
#          'video_frame_number': 14700,
#          'exported_clip_frame_number': 1200,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 201,
#          'x': 1120.25,
#          'y': 639.03,
#          'width': 122.48,
#          'height': 233.11,
#          'video_frame_number': 14706,
#          'exported_clip_frame_number': 1206,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 202,
#          'x': 1128.26,
#          'y': 632.75,
#          'width': 70.9,
#          'height': 45.64,
#          'video_frame_number': 14712,
#          'exported_clip_frame_number': 1212,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 203,
#          'x': 1243.37,
#          'y': 830.72,
#          'width': 42.36,
#          'height': 25.72,
#          'video_frame_number': 14718,
#          'exported_clip_frame_number': 1218,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 204,
#          'x': 1231.17,
#          'y': 759.13,
#          'width': 96.44,
#          'height': 67.64,
#          'video_frame_number': 14724,
#          'exported_clip_frame_number': 1224,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 205,
#          'x': 1210.44,
#          'y': 747.19,
#          'width': 116.14,
#          'height': 78.59,
#          'video_frame_number': 14730,
#          'exported_clip_frame_number': 1230,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 206,
#          'x': 1125.82,
#          'y': 630.6,
#          'width': 65.23,
#          'height': 42.29,
#          'video_frame_number': 14736,
#          'exported_clip_frame_number': 1236,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 207,
#          'x': 1113.91,
#          'y': 662.11,
#          'width': 58.88,
#          'height': 38.84,
#          'video_frame_number': 14742,
#          'exported_clip_frame_number': 1242,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 208,
#          'x': 1095.38,
#          'y': 651.3,
#          'width': 53.23,
#          'height': 34.66,
#          'video_frame_number': 14748,
#          'exported_clip_frame_number': 1248,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 209,
#          'x': 1116.36,
#          'y': 649.32,
#          'width': 55.31,
#          'height': 32.27,
#          'video_frame_number': 14754,
#          'exported_clip_frame_number': 1254,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 210,
#          'x': 1138.42,
#          'y': 757.62,
#          'width': 98.95,
#          'height': 160.5,
#          'video_frame_number': 14760,
#          'exported_clip_frame_number': 1260,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 211,
#          'x': 1124.7,
#          'y': 749.71,
#          'width': 94.05,
#          'height': 159.27,
#          'video_frame_number': 14766,
#          'exported_clip_frame_number': 1266,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 212,
#          'x': 1143.56,
#          'y': 801.95,
#          'width': 63.54,
#          'height': 96.82,
#          'video_frame_number': 14772,
#          'exported_clip_frame_number': 1272,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 213,
#          'x': 1118.77,
#          'y': 639.8,
#          'width': 56.34,
#          'height': 56.7,
#          'video_frame_number': 14778,
#          'exported_clip_frame_number': 1278,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 214,
#          'x': 1112.2,
#          'y': 731.25,
#          'width': 89.58,
#          'height': 165.67,
#          'video_frame_number': 14784,
#          'exported_clip_frame_number': 1284,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 215,
#          'x': 1104.89,
#          'y': 642.58,
#          'width': 99.92,
#          'height': 257.15,
#          'video_frame_number': 14790,
#          'exported_clip_frame_number': 1290,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 216,
#          'x': 1108.24,
#          'y': 652.82,
#          'width': 75.76,
#          'height': 250.73,
#          'video_frame_number': 14796,
#          'exported_clip_frame_number': 1296,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 217,
#          'x': 1120.75,
#          'y': 666.79,
#          'width': 69.5,
#          'height': 233.31,
#          'video_frame_number': 14802,
#          'exported_clip_frame_number': 1302,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 218,
#          'x': 1106.4,
#          'y': 651.54,
#          'width': 101.29,
#          'height': 252.24,
#          'video_frame_number': 14808,
#          'exported_clip_frame_number': 1308,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 219,
#          'x': 1103.86,
#          'y': 647.62,
#          'width': 87.62,
#          'height': 237.8,
#          'video_frame_number': 14814,
#          'exported_clip_frame_number': 1314,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 220,
#          'x': 1112.82,
#          'y': 650.81,
#          'width': 93.03,
#          'height': 248.44,
#          'video_frame_number': 14820,
#          'exported_clip_frame_number': 1320,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 221,
#          'x': 1143.07,
#          'y': 702.62,
#          'width': 62.49,
#          'height': 225,
#          'video_frame_number': 14826,
#          'exported_clip_frame_number': 1326,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 222,
#          'x': 1118.06,
#          'y': 682.01,
#          'width': 71.07,
#          'height': 226.28,
#          'video_frame_number': 14832,
#          'exported_clip_frame_number': 1332,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 223,
#          'x': 1098.79,
#          'y': 662.23,
#          'width': 59.76,
#          'height': 56.45,
#          'video_frame_number': 14838,
#          'exported_clip_frame_number': 1338,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 225,
#          'x': 1099.26,
#          'y': 660.86,
#          'width': 70.56,
#          'height': 248.19,
#          'video_frame_number': 14850,
#          'exported_clip_frame_number': 1350,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 226,
#          'x': 1089.02,
#          'y': 660.27,
#          'width': 86.1,
#          'height': 242.88,
#          'video_frame_number': 14856,
#          'exported_clip_frame_number': 1356,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 227,
#          'x': 1115.06,
#          'y': 688.15,
#          'width': 55.16,
#          'height': 217.77,
#          'video_frame_number': 14862,
#          'exported_clip_frame_number': 1362,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 228,
#          'x': 1122.12,
#          'y': 685.23,
#          'width': 47.38,
#          'height': 216.78,
#          'video_frame_number': 14868,
#          'exported_clip_frame_number': 1368,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 229,
#          'x': 1125.22,
#          'y': 686.35,
#          'width': 51.9,
#          'height': 218.01,
#          'video_frame_number': 14874,
#          'exported_clip_frame_number': 1374,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 230,
#          'x': 1115.01,
#          'y': 757.82,
#          'width': 79.73,
#          'height': 163.08,
#          'video_frame_number': 14880,
#          'exported_clip_frame_number': 1380,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 231,
#          'x': 1103.01,
#          'y': 675.26,
#          'width': 85.09,
#          'height': 244.84,
#          'video_frame_number': 14886,
#          'exported_clip_frame_number': 1386,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 232,
#          'x': 1116.59,
#          'y': 768.56,
#          'width': 77.62,
#          'height': 146.2,
#          'video_frame_number': 14892,
#          'exported_clip_frame_number': 1392,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 233,
#          'x': 1110.98,
#          'y': 766.53,
#          'width': 82.23,
#          'height': 147.39,
#          'video_frame_number': 14898,
#          'exported_clip_frame_number': 1398,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 224,
#          'x': 1100.43,
#          'y': 661.46,
#          'width': 57.25,
#          'height': 56.55,
#          'video_frame_number': 14844,
#          'exported_clip_frame_number': 1344,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 234,
#          'x': 1109.91,
#          'y': 819.2,
#          'width': 63.32,
#          'height': 98.73,
#          'video_frame_number': 14904,
#          'exported_clip_frame_number': 1404,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 235,
#          'x': 1112.9,
#          'y': 688.27,
#          'width': 69.33,
#          'height': 239.89,
#          'video_frame_number': 14910,
#          'exported_clip_frame_number': 1410,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 236,
#          'x': 1094.28,
#          'y': 772.59,
#          'width': 76.85,
#          'height': 151.71,
#          'video_frame_number': 14916,
#          'exported_clip_frame_number': 1416,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 237,
#          'x': 1110.27,
#          'y': 677.62,
#          'width': 69.5,
#          'height': 247.38,
#          'video_frame_number': 14922,
#          'exported_clip_frame_number': 1422,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 238,
#          'x': 1109.2,
#          'y': 676.91,
#          'width': 62.61,
#          'height': 241.25,
#          'video_frame_number': 14928,
#          'exported_clip_frame_number': 1428,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 239,
#          'x': 1100.3,
#          'y': 676.57,
#          'width': 66.52,
#          'height': 240.12,
#          'video_frame_number': 14934,
#          'exported_clip_frame_number': 1434,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 240,
#          'x': 1098.64,
#          'y': 671.16,
#          'width': 60.6,
#          'height': 244.84,
#          'video_frame_number': 14940,
#          'exported_clip_frame_number': 1440,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 241,
#          'x': 1098.98,
#          'y': 660.65,
#          'width': 54.67,
#          'height': 61.51,
#          'video_frame_number': 14946,
#          'exported_clip_frame_number': 1446,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 242,
#          'x': 1129.08,
#          'y': 681.73,
#          'width': 64.38,
#          'height': 73.36,
#          'video_frame_number': 14952,
#          'exported_clip_frame_number': 1452,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 243,
#          'x': 1119.2,
#          'y': 692.41,
#          'width': 54.84,
#          'height': 49.54,
#          'video_frame_number': 14958,
#          'exported_clip_frame_number': 1458,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 244,
#          'x': 1113.81,
#          'y': 687.35,
#          'width': 48.41,
#          'height': 59,
#          'video_frame_number': 14964,
#          'exported_clip_frame_number': 1464,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 245,
#          'x': 1108.12,
#          'y': 682.22,
#          'width': 59.52,
#          'height': 66.9,
#          'video_frame_number': 14970,
#          'exported_clip_frame_number': 1470,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 246,
#          'x': 1098.61,
#          'y': 775.67,
#          'width': 90.21,
#          'height': 173.65,
#          'video_frame_number': 14976,
#          'exported_clip_frame_number': 1476,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 247,
#          'x': 1097.35,
#          'y': 783.73,
#          'width': 84.95,
#          'height': 160.98,
#          'video_frame_number': 14982,
#          'exported_clip_frame_number': 1482,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 248,
#          'x': 1102.99,
#          'y': 693.91,
#          'width': 75.14,
#          'height': 247.29,
#          'video_frame_number': 14988,
#          'exported_clip_frame_number': 1488,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 249,
#          'x': 1097.85,
#          'y': 696.8,
#          'width': 67.65,
#          'height': 241.86,
#          'video_frame_number': 14994,
#          'exported_clip_frame_number': 1494,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 250,
#          'x': 1096.2,
#          'y': 699.76,
#          'width': 68.33,
#          'height': 238.7,
#          'video_frame_number': 15000,
#          'exported_clip_frame_number': 1500,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 251,
#          'x': 1097.3,
#          'y': 699.01,
#          'width': 76.45,
#          'height': 236.69,
#          'video_frame_number': 15006,
#          'exported_clip_frame_number': 1506,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 252,
#          'x': 1114.48,
#          'y': 875.51,
#          'width': 33.25,
#          'height': 47.01,
#          'video_frame_number': 15012,
#          'exported_clip_frame_number': 1512,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 253,
#          'x': 1106.28,
#          'y': 685.25,
#          'width': 70.32,
#          'height': 68.82,
#          'video_frame_number': 15018,
#          'exported_clip_frame_number': 1518,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 254,
#          'x': 1125.4,
#          'y': 852.89,
#          'width': 31.2,
#          'height': 22.56,
#          'video_frame_number': 15024,
#          'exported_clip_frame_number': 1524,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 255,
#          'x': 1125.11,
#          'y': 688.13,
#          'width': 71.58,
#          'height': 68.25,
#          'video_frame_number': 15030,
#          'exported_clip_frame_number': 1530,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 256,
#          'x': 1134.01,
#          'y': 847.27,
#          'width': 27.77,
#          'height': 16.88,
#          'video_frame_number': 15036,
#          'exported_clip_frame_number': 1536,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 257,
#          'x': 1135.5,
#          'y': 695.59,
#          'width': 72.68,
#          'height': 69.95,
#          'video_frame_number': 15042,
#          'exported_clip_frame_number': 1542,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 258,
#          'x': 1137.3,
#          'y': 695.35,
#          'width': 55.45,
#          'height': 55.76,
#          'video_frame_number': 15048,
#          'exported_clip_frame_number': 1548,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 259,
#          'x': 1124.38,
#          'y': 787.81,
#          'width': 77.15,
#          'height': 168.68,
#          'video_frame_number': 15054,
#          'exported_clip_frame_number': 1554,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 260,
#          'x': 1120.15,
#          'y': 784.58,
#          'width': 77.7,
#          'height': 170.64,
#          'video_frame_number': 15060,
#          'exported_clip_frame_number': 1560,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 261,
#          'x': 1118.22,
#          'y': 782.28,
#          'width': 90.87,
#          'height': 187.01,
#          'video_frame_number': 15066,
#          'exported_clip_frame_number': 1566,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 262,
#          'x': 1112.33,
#          'y': 848.4,
#          'width': 82.55,
#          'height': 90.57,
#          'video_frame_number': 15072,
#          'exported_clip_frame_number': 1572,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 263,
#          'x': 1135.18,
#          'y': 722.73,
#          'width': 17.28,
#          'height': 11.83,
#          'video_frame_number': 15078,
#          'exported_clip_frame_number': 1578,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 264,
#          'x': 1075.72,
#          'y': 731.29,
#          'width': 87.39,
#          'height': 235.3,
#          'video_frame_number': 15084,
#          'exported_clip_frame_number': 1584,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 265,
#          'x': 1088.71,
#          'y': 705.3,
#          'width': 61.38,
#          'height': 80.16,
#          'video_frame_number': 15090,
#          'exported_clip_frame_number': 1590,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 266,
#          'x': 1345.76,
#          'y': 549.46,
#          'width': 41.71,
#          'height': 76.46,
#          'video_frame_number': 15096,
#          'exported_clip_frame_number': 1596,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 267,
#          'x': 1399.04,
#          'y': 367.27,
#          'width': 66.26,
#          'height': 78.91,
#          'video_frame_number': 15102,
#          'exported_clip_frame_number': 1602,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 268,
#          'x': 1380.68,
#          'y': 273.26,
#          'width': 190.11,
#          'height': 131.52,
#          'video_frame_number': 15108,
#          'exported_clip_frame_number': 1608,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 269,
#          'x': 1374.49,
#          'y': 276.18,
#          'width': 161.99,
#          'height': 142.44,
#          'video_frame_number': 15114,
#          'exported_clip_frame_number': 1614,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 270,
#          'x': 1374.61,
#          'y': 270.14,
#          'width': 141.81,
#          'height': 143.6,
#          'video_frame_number': 15120,
#          'exported_clip_frame_number': 1620,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 271,
#          'x': 1378.24,
#          'y': 268.37,
#          'width': 138.37,
#          'height': 141.05,
#          'video_frame_number': 15126,
#          'exported_clip_frame_number': 1626,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 272,
#          'x': 1410.74,
#          'y': 272.37,
#          'width': 129.35,
#          'height': 131.05,
#          'video_frame_number': 15132,
#          'exported_clip_frame_number': 1632,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 273,
#          'x': 1595.94,
#          'y': 346.7,
#          'width': 93.01,
#          'height': 58.24,
#          'video_frame_number': 15138,
#          'exported_clip_frame_number': 1638,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 274,
#          'x': 1788.69,
#          'y': 300.35,
#          'width': 131.64,
#          'height': 87.04,
#          'video_frame_number': 15144,
#          'exported_clip_frame_number': 1644,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 275,
#          'x': 1868.31,
#          'y': 315.63,
#          'width': 52.16,
#          'height': 72.1,
#          'video_frame_number': 15150,
#          'exported_clip_frame_number': 1650,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 307,
#          'x': 1909.16,
#          'y': 489.49,
#          'width': 10.86,
#          'height': 56.73,
#          'video_frame_number': 15342,
#          'exported_clip_frame_number': 1842,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 308,
#          'x': 1768.79,
#          'y': 472.07,
#          'width': 84.34,
#          'height': 44.91,
#          'video_frame_number': 15348,
#          'exported_clip_frame_number': 1848,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 309,
#          'x': 1506.7,
#          'y': 350.69,
#          'width': 142.65,
#          'height': 129.02,
#          'video_frame_number': 15354,
#          'exported_clip_frame_number': 1854,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 310,
#          'x': 1459.38,
#          'y': 345.13,
#          'width': 139.01,
#          'height': 135.55,
#          'video_frame_number': 15360,
#          'exported_clip_frame_number': 1860,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 311,
#          'x': 1557.67,
#          'y': 385.57,
#          'width': 189.16,
#          'height': 145.4,
#          'video_frame_number': 15366,
#          'exported_clip_frame_number': 1866,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 312,
#          'x': 1494.57,
#          'y': 480.04,
#          'width': 161.87,
#          'height': 225.41,
#          'video_frame_number': 15372,
#          'exported_clip_frame_number': 1872,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 313,
#          'x': 1244.87,
#          'y': 701.88,
#          'width': 252.75,
#          'height': 378.34,
#          'video_frame_number': 15378,
#          'exported_clip_frame_number': 1878,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 314,
#          'x': 1066.68,
#          'y': 703.12,
#          'width': 126.97,
#          'height': 299.69,
#          'video_frame_number': 15384,
#          'exported_clip_frame_number': 1884,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 315,
#          'x': 1023.97,
#          'y': 711.96,
#          'width': 135.9,
#          'height': 214.14,
#          'video_frame_number': 15390,
#          'exported_clip_frame_number': 1890,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 316,
#          'x': 1018.75,
#          'y': 679.75,
#          'width': 151.12,
#          'height': 210.78,
#          'video_frame_number': 15396,
#          'exported_clip_frame_number': 1896,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 317,
#          'x': 1027.05,
#          'y': 702.28,
#          'width': 135.97,
#          'height': 178.08,
#          'video_frame_number': 15402,
#          'exported_clip_frame_number': 1902,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 318,
#          'x': 1029.83,
#          'y': 687.99,
#          'width': 133.82,
#          'height': 190.82,
#          'video_frame_number': 15408,
#          'exported_clip_frame_number': 1908,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 319,
#          'x': 1004.59,
#          'y': 678.14,
#          'width': 126.46,
#          'height': 207.99,
#          'video_frame_number': 15414,
#          'exported_clip_frame_number': 1914,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 320,
#          'x': 1002.89,
#          'y': 677.37,
#          'width': 127.14,
#          'height': 207.88,
#          'video_frame_number': 15420,
#          'exported_clip_frame_number': 1920,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 321,
#          'x': 1014.71,
#          'y': 677.96,
#          'width': 126.09,
#          'height': 211,
#          'video_frame_number': 15426,
#          'exported_clip_frame_number': 1926,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 322,
#          'x': 998.65,
#          'y': 671.4,
#          'width': 129.36,
#          'height': 208.82,
#          'video_frame_number': 15432,
#          'exported_clip_frame_number': 1932,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 323,
#          'x': 1027.53,
#          'y': 695.16,
#          'width': 132.91,
#          'height': 210.16,
#          'video_frame_number': 15438,
#          'exported_clip_frame_number': 1938,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 324,
#          'x': 1055.18,
#          'y': 696.69,
#          'width': 147.71,
#          'height': 192,
#          'video_frame_number': 15444,
#          'exported_clip_frame_number': 1944,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 325,
#          'x': 1057.66,
#          'y': 702.47,
#          'width': 189.78,
#          'height': 241.71,
#          'video_frame_number': 15450,
#          'exported_clip_frame_number': 1950,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 326,
#          'x': 1037.22,
#          'y': 693.56,
#          'width': 224.62,
#          'height': 255.37,
#          'video_frame_number': 15456,
#          'exported_clip_frame_number': 1956,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 327,
#          'x': 1004.28,
#          'y': 677.78,
#          'width': 235.14,
#          'height': 243.66,
#          'video_frame_number': 15462,
#          'exported_clip_frame_number': 1962,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 328,
#          'x': 1004.73,
#          'y': 671.82,
#          'width': 234.33,
#          'height': 243.07,
#          'video_frame_number': 15468,
#          'exported_clip_frame_number': 1968,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 329,
#          'x': 1083.04,
#          'y': 685.53,
#          'width': 231.57,
#          'height': 271.09,
#          'video_frame_number': 15474,
#          'exported_clip_frame_number': 1974,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 330,
#          'x': 1117.63,
#          'y': 680.92,
#          'width': 222.01,
#          'height': 260.95,
#          'video_frame_number': 15480,
#          'exported_clip_frame_number': 1980,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 331,
#          'x': 1062.65,
#          'y': 664.74,
#          'width': 219.58,
#          'height': 260.72,
#          'video_frame_number': 15486,
#          'exported_clip_frame_number': 1986,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 332,
#          'x': 1046.88,
#          'y': 666.11,
#          'width': 237.15,
#          'height': 240.67,
#          'video_frame_number': 15492,
#          'exported_clip_frame_number': 1992,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 333,
#          'x': 1058.69,
#          'y': 668.18,
#          'width': 250.33,
#          'height': 223.36,
#          'video_frame_number': 15498,
#          'exported_clip_frame_number': 1998,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 334,
#          'x': 1061.91,
#          'y': 650.88,
#          'width': 247.49,
#          'height': 199.86,
#          'video_frame_number': 15504,
#          'exported_clip_frame_number': 2004,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 335,
#          'x': 1084.03,
#          'y': 632.84,
#          'width': 246.73,
#          'height': 204.54,
#          'video_frame_number': 15510,
#          'exported_clip_frame_number': 2010,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 336,
#          'x': 1094.32,
#          'y': 630.59,
#          'width': 249.05,
#          'height': 208.81,
#          'video_frame_number': 15516,
#          'exported_clip_frame_number': 2016,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 337,
#          'x': 1109.97,
#          'y': 679.99,
#          'width': 259.5,
#          'height': 230.31,
#          'video_frame_number': 15522,
#          'exported_clip_frame_number': 2022,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 338,
#          'x': 1018.01,
#          'y': 716.04,
#          'width': 183.4,
#          'height': 132.41,
#          'video_frame_number': 15528,
#          'exported_clip_frame_number': 2028,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 339,
#          'x': 950.37,
#          'y': 678.26,
#          'width': 177.96,
#          'height': 133.06,
#          'video_frame_number': 15534,
#          'exported_clip_frame_number': 2034,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 340,
#          'x': 906.44,
#          'y': 665.95,
#          'width': 180.02,
#          'height': 128.59,
#          'video_frame_number': 15540,
#          'exported_clip_frame_number': 2040,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 341,
#          'x': 896.39,
#          'y': 664.54,
#          'width': 186.83,
#          'height': 136.5,
#          'video_frame_number': 15546,
#          'exported_clip_frame_number': 2046,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 342,
#          'x': 920.71,
#          'y': 663.14,
#          'width': 161.53,
#          'height': 137.08,
#          'video_frame_number': 15552,
#          'exported_clip_frame_number': 2052,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 343,
#          'x': 943.28,
#          'y': 653.26,
#          'width': 157.43,
#          'height': 126.54,
#          'video_frame_number': 15558,
#          'exported_clip_frame_number': 2058,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 344,
#          'x': 1010.58,
#          'y': 604.35,
#          'width': 175.89,
#          'height': 149.77,
#          'video_frame_number': 15564,
#          'exported_clip_frame_number': 2064,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 345,
#          'x': 1073.22,
#          'y': 684.98,
#          'width': 177.64,
#          'height': 138.06,
#          'video_frame_number': 15570,
#          'exported_clip_frame_number': 2070,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 346,
#          'x': 1067.98,
#          'y': 684.46,
#          'width': 171.51,
#          'height': 154.15,
#          'video_frame_number': 15576,
#          'exported_clip_frame_number': 2076,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 347,
#          'x': 978.71,
#          'y': 696.96,
#          'width': 236,
#          'height': 158.85,
#          'video_frame_number': 15582,
#          'exported_clip_frame_number': 2082,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 348,
#          'x': 949.12,
#          'y': 691.05,
#          'width': 223.58,
#          'height': 144.08,
#          'video_frame_number': 15588,
#          'exported_clip_frame_number': 2088,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 349,
#          'x': 944.85,
#          'y': 682.28,
#          'width': 229.1,
#          'height': 153.87,
#          'video_frame_number': 15594,
#          'exported_clip_frame_number': 2094,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 350,
#          'x': 957.02,
#          'y': 696.6,
#          'width': 225.6,
#          'height': 137.12,
#          'video_frame_number': 15600,
#          'exported_clip_frame_number': 2100,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 351,
#          'x': 1101.96,
#          'y': 741.83,
#          'width': 196.97,
#          'height': 155.8,
#          'video_frame_number': 15606,
#          'exported_clip_frame_number': 2106,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 352,
#          'x': 1029.19,
#          'y': 729.81,
#          'width': 188.44,
#          'height': 143.16,
#          'video_frame_number': 15612,
#          'exported_clip_frame_number': 2112,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 353,
#          'x': 1039.43,
#          'y': 710.37,
#          'width': 163.18,
#          'height': 140.94,
#          'video_frame_number': 15618,
#          'exported_clip_frame_number': 2118,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 354,
#          'x': 1037.29,
#          'y': 705.74,
#          'width': 159.6,
#          'height': 136.87,
#          'video_frame_number': 15624,
#          'exported_clip_frame_number': 2124,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 355,
#          'x': 1045.57,
#          'y': 711.99,
#          'width': 145.5,
#          'height': 91.26,
#          'video_frame_number': 15630,
#          'exported_clip_frame_number': 2130,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 356,
#          'x': 1053.67,
#          'y': 721.33,
#          'width': 138.15,
#          'height': 89.43,
#          'video_frame_number': 15636,
#          'exported_clip_frame_number': 2136,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 357,
#          'x': 1052.92,
#          'y': 745.71,
#          'width': 146.29,
#          'height': 116.34,
#          'video_frame_number': 15642,
#          'exported_clip_frame_number': 2142,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 358,
#          'x': 1061.04,
#          'y': 684.2,
#          'width': 135.44,
#          'height': 117.98,
#          'video_frame_number': 15648,
#          'exported_clip_frame_number': 2148,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 359,
#          'x': 1032.51,
#          'y': 744.03,
#          'width': 157.64,
#          'height': 93.08,
#          'video_frame_number': 15654,
#          'exported_clip_frame_number': 2154,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 360,
#          'x': 1007.52,
#          'y': 701.53,
#          'width': 150.99,
#          'height': 127.69,
#          'video_frame_number': 15660,
#          'exported_clip_frame_number': 2160,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 361,
#          'x': 873.96,
#          'y': 721.96,
#          'width': 177.55,
#          'height': 164.42,
#          'video_frame_number': 15666,
#          'exported_clip_frame_number': 2166,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 362,
#          'x': 968.32,
#          'y': 454.83,
#          'width': 103.46,
#          'height': 123.12,
#          'video_frame_number': 15672,
#          'exported_clip_frame_number': 2172,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 363,
#          'x': 1073.92,
#          'y': 476.98,
#          'width': 69.22,
#          'height': 36.61,
#          'video_frame_number': 15678,
#          'exported_clip_frame_number': 2178,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 364,
#          'x': 1349.9,
#          'y': 407.76,
#          'width': 59.45,
#          'height': 36.65,
#          'video_frame_number': 15684,
#          'exported_clip_frame_number': 2184,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 365,
#          'x': 1652.18,
#          'y': 226.17,
#          'width': 15.36,
#          'height': 26.78,
#          'video_frame_number': 15690,
#          'exported_clip_frame_number': 2190,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 366,
#          'x': 1522.34,
#          'y': 172.63,
#          'width': 64.21,
#          'height': 22.03,
#          'video_frame_number': 15696,
#          'exported_clip_frame_number': 2196,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 367,
#          'x': 1539.61,
#          'y': 170.91,
#          'width': 101.22,
#          'height': 122.52,
#          'video_frame_number': 15702,
#          'exported_clip_frame_number': 2202,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 368,
#          'x': 1639.68,
#          'y': 203.12,
#          'width': 88.28,
#          'height': 118.09,
#          'video_frame_number': 15708,
#          'exported_clip_frame_number': 2208,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 369,
#          'x': 1870.27,
#          'y': 448,
#          'width': 49.82,
#          'height': 84.4,
#          'video_frame_number': 15714,
#          'exported_clip_frame_number': 2214,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 411,
#          'x': 1352.26,
#          'y': 0.29,
#          'width': 5.9,
#          'height': 1.18,
#          'video_frame_number': 15966,
#          'exported_clip_frame_number': 2466,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 412,
#          'x': 1489.63,
#          'y': 0.29,
#          'width': 128.73,
#          'height': 92.49,
#          'video_frame_number': 15972,
#          'exported_clip_frame_number': 2472,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 451,
#          'x': 474.27,
#          'y': -0.01,
#          'width': 89.9,
#          'height': 20.41,
#          'video_frame_number': 16206,
#          'exported_clip_frame_number': 2706,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 452,
#          'x': 430.33,
#          'y': 20.55,
#          'width': 155.2,
#          'height': 111.29,
# ...
#          'original_height': 1080},
#         {'frame_number': 1473,
#          'x': 1656.17,
#          'y': 370.18,
#          'width': 216.5,
#          'height': 361.49,
#          'video_frame_number': 8838,
#          'exported_clip_frame_number': 8838,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1474,
#          'x': 1638.29,
#          'y': 362.23,
#          'width': 218.48,
#          'height': 361.49,
#          'video_frame_number': 8844,
#          'exported_clip_frame_number': 8844,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1475,
#          'x': 1630.34,
#          'y': 362.23,
#          'width': 218.48,
#          'height': 357.52,
#          'video_frame_number': 8850,
#          'exported_clip_frame_number': 8850,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1476,
#          'x': 1624.39,
#          'y': 362.23,
#          'width': 218.48,
#          'height': 357.52,
#          'video_frame_number': 8856,
#          'exported_clip_frame_number': 8856,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1477,
#          'x': 1624.39,
#          'y': 362.23,
#          'width': 218.48,
#          'height': 357.52,
#          'video_frame_number': 8862,
#          'exported_clip_frame_number': 8862,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1478,
#          'x': 1624.39,
#          'y': 370.18,
#          'width': 218.48,
#          'height': 349.57,
#          'video_frame_number': 8868,
#          'exported_clip_frame_number': 8868,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1479,
#          'x': 1646.23,
#          'y': 384.08,
#          'width': 224.44,
#          'height': 357.52,
#          'video_frame_number': 8874,
#          'exported_clip_frame_number': 8874,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1480,
#          'x': 1699.86,
#          'y': 413.88,
#          'width': 210.54,
#          'height': 365.46,
#          'video_frame_number': 8880,
#          'exported_clip_frame_number': 8880,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1481,
#          'x': 1771.37,
#          'y': 447.64,
#          'width': 146.98,
#          'height': 409.16,
#          'video_frame_number': 8886,
#          'exported_clip_frame_number': 8886,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1184,
#          'x': 1877.63,
#          'y': 339.39,
#          'width': 41.71,
#          'height': 215.5,
#          'video_frame_number': 7104,
#          'exported_clip_frame_number': 7104,
#          'original_width': 1920,
#          'original_height': 1080}],
#        'attributes_occurrence': [{'start_frame_number': 20,
#          'end_frame_number': 30,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 120,
#          'exported_clip_start_frame_number': 120,
#          'video_end_frame_number': 180,
#          'exported_clip_end_frame_number': 180},
#         {'start_frame_number': 128,
#          'end_frame_number': 132,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 768,
#          'exported_clip_start_frame_number': 768,
#          'video_end_frame_number': 792,
#          'exported_clip_end_frame_number': 792},
#         {'start_frame_number': 206,
#          'end_frame_number': 209,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 1236,
#          'exported_clip_start_frame_number': 1236,
#          'video_end_frame_number': 1254,
#          'exported_clip_end_frame_number': 1254},
#         {'start_frame_number': 300,
#          'end_frame_number': 303,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 1800,
#          'exported_clip_start_frame_number': 1800,
#          'video_end_frame_number': 1818,
#          'exported_clip_end_frame_number': 1818},
#         {'start_frame_number': 342,
#          'end_frame_number': 344,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 2052,
#          'exported_clip_start_frame_number': 2052,
#          'video_end_frame_number': 2064,
#          'exported_clip_end_frame_number': 2064},
#         {'start_frame_number': 465,
#          'end_frame_number': 469,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 2790,
#          'exported_clip_start_frame_number': 2790,
#          'video_end_frame_number': 2814,
#          'exported_clip_end_frame_number': 2814},
#         {'start_frame_number': 507,
#          'end_frame_number': 510,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 3042,
#          'exported_clip_start_frame_number': 3042,
#          'video_end_frame_number': 3060,
#          'exported_clip_end_frame_number': 3060},
#         {'start_frame_number': 558,
#          'end_frame_number': 559,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 3348,
#          'exported_clip_start_frame_number': 3348,
#          'video_end_frame_number': 3354,
#          'exported_clip_end_frame_number': 3354},
#         {'start_frame_number': 681,
#          'end_frame_number': 692,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 4086,
#          'exported_clip_start_frame_number': 4086,
#          'video_end_frame_number': 4152,
#          'exported_clip_end_frame_number': 4152},
#         {'start_frame_number': 715,
#          'end_frame_number': 724,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 4290,
#          'exported_clip_start_frame_number': 4290,
#          'video_end_frame_number': 4344,
#          'exported_clip_end_frame_number': 4344},
#         {'start_frame_number': 767,
#          'end_frame_number': 774,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 4602,
#          'exported_clip_start_frame_number': 4602,
#          'video_end_frame_number': 4644,
#          'exported_clip_end_frame_number': 4644},
#         {'start_frame_number': 938,
#          'end_frame_number': 942,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 5628,
#          'exported_clip_start_frame_number': 5628,
#          'video_end_frame_number': 5652,
#          'exported_clip_end_frame_number': 5652},
#         {'start_frame_number': 1075,
#          'end_frame_number': 1079,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 6450,
#          'exported_clip_start_frame_number': 6450,
#          'video_end_frame_number': 6474,
#          'exported_clip_end_frame_number': 6474},
#         {'start_frame_number': 1157,
#          'end_frame_number': 1169,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 6942,
#          'exported_clip_start_frame_number': 6942,
#          'video_end_frame_number': 7014,
#          'exported_clip_end_frame_number': 7014},
#         {'start_frame_number': 1178,
#          'end_frame_number': 1183,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 7068,
#          'exported_clip_start_frame_number': 7068,
#          'video_end_frame_number': 7098,
#          'exported_clip_end_frame_number': 7098},
#         {'start_frame_number': 1185,
#          'end_frame_number': 1192,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 7110,
#          'exported_clip_start_frame_number': 7110,
#          'video_end_frame_number': 7152,
#          'exported_clip_end_frame_number': 7152},
#         {'start_frame_number': 1269,
#          'end_frame_number': 1275,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 7614,
#          'exported_clip_start_frame_number': 7614,
#          'video_end_frame_number': 7650,
#          'exported_clip_end_frame_number': 7650},
#         {'start_frame_number': 1298,
#          'end_frame_number': 1299,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 7788,
#          'exported_clip_start_frame_number': 7788,
#          'video_end_frame_number': 7794,
#          'exported_clip_end_frame_number': 7794},
#         {'start_frame_number': 1311,
#          'end_frame_number': 1317,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 7866,
#          'exported_clip_start_frame_number': 7866,
#          'video_end_frame_number': 7902,
#          'exported_clip_end_frame_number': 7902},
#         {'start_frame_number': 1348,
#          'end_frame_number': 1350,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 8088,
#          'exported_clip_start_frame_number': 8088,
#          'video_end_frame_number': 8100,
#          'exported_clip_end_frame_number': 8100},
#         {'start_frame_number': 1367,
#          'end_frame_number': 1378,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 8202,
#          'exported_clip_start_frame_number': 8202,
#          'video_end_frame_number': 8268,
#          'exported_clip_end_frame_number': 8268},
#         {'start_frame_number': 1403,
#          'end_frame_number': 1427,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 8418,
#          'exported_clip_start_frame_number': 8418,
#          'video_end_frame_number': 8562,
#          'exported_clip_end_frame_number': 8562},
#         {'start_frame_number': 1466,
#          'end_frame_number': 1481,
#          'is_location_changed': False,
#          'is_moving': False,
#          'is_active': False,
#          'is_transformed': False,
#          'is_recognizable': True,
#          'video_start_frame_number': 8796,
#          'exported_clip_start_frame_number': 8796,
#          'video_end_frame_number': 8886,
#          'exported_clip_end_frame_number': 8886}],
#        'visual_clip': [{'frame_number': 1367,
#          'x': 1604.52,
#          'y': 247.03,
#          'width': 313.82,
#          'height': 357.52,
#          'video_frame_number': 8202,
#          'exported_clip_frame_number': 8202,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1368,
#          'x': 1378.1,
#          'y': 145.74,
#          'width': 369.43,
#          'height': 325.74,
#          'video_frame_number': 8208,
#          'exported_clip_frame_number': 8208,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1369,
#          'x': 1272.83,
#          'y': 111.97,
#          'width': 351.56,
#          'height': 327.72,
#          'video_frame_number': 8214,
#          'exported_clip_frame_number': 8214,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1370,
#          'x': 1227.14,
#          'y': 135.81,
#          'width': 335.67,
#          'height': 313.82,
#          'video_frame_number': 8220,
#          'exported_clip_frame_number': 8220,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1371,
#          'x': 1241.05,
#          'y': 155.67,
#          'width': 347.59,
#          'height': 319.78,
#          'video_frame_number': 8226,
#          'exported_clip_frame_number': 8226,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1372,
#          'x': 1254.95,
#          'y': 197.38,
#          'width': 355.53,
#          'height': 327.72,
#          'video_frame_number': 8232,
#          'exported_clip_frame_number': 8232,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1373,
#          'x': 1237.08,
#          'y': 256.97,
#          'width': 359.5,
#          'height': 339.64,
#          'video_frame_number': 8238,
#          'exported_clip_frame_number': 8238,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1374,
#          'x': 1225.16,
#          'y': 324.5,
#          'width': 373.41,
#          'height': 339.64,
#          'video_frame_number': 8244,
#          'exported_clip_frame_number': 8244,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1375,
#          'x': 1149.68,
#          'y': 380.11,
#          'width': 369.43,
#          'height': 353.54,
#          'video_frame_number': 8250,
#          'exported_clip_frame_number': 8250,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1376,
#          'x': 1179.48,
#          'y': 417.85,
#          'width': 373.41,
#          'height': 353.54,
#          'video_frame_number': 8256,
#          'exported_clip_frame_number': 8256,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1377,
#          'x': 1509.19,
#          'y': 467.5,
#          'width': 220.47,
#          'height': 325.74,
#          'video_frame_number': 8262,
#          'exported_clip_frame_number': 8262,
#          'original_width': 1920,
#          'original_height': 1080},
#         {'frame_number': 1378,
#          'x': 1570.76,
#          'y': 523.12,
#          'width': 347.59,
#          'height': 373.41,
#          'video_frame_number': 8268,
#          'exported_clip_frame_number': 8268,
#          'original_width': 1920,
#          'original_height': 1080}],
#        'query_exported_clip_frame': 7770}}}],
#    'exported_clip_uid': 'bd365d25-88d0-4e4b-868a-59a01b134a42'}]}

# %%
p_ann_dir = Path('/data/soyeonhong/vq2d/vq2d-lightning/data')

for split in ['val', 'train']:
    p_track_ann = Path(f"/data/datasets/ego4d_data/v2/egotracks/egotracks_{split}.json")
    track_anns = json.load(p_track_ann.open())
    flat_anns = generate_flat_annotations_egotracks(track_anns)
    
    p_ann = p_ann_dir / f'egotracks_v1_{split}.json'
    
    json.dump(flat_anns, p_ann.open('w'))

# %%
all_anns = json.load(open('/data/soyeonhong/vq2d/vq2d-lightning/data/egotracks_v1_train.json'))
all_anns[0]
# Out:
# {'video_uid': '57ab94d1-56d2-4227-b099-7388d4cefcbf',
#  'clip_uid': '622c1b29-76c6-4845-95df-7e54792687d4',
#  'annotation_uid': '622c1b29-76c6-4845-95df-7e54792687d4_1',
#  'query_set': '1',
#  'clip_fps': 5.0,
#  'clip_duration': 300.00000000000006,
#  'original_width': 1920,
#  'original_height': 1440,
#  'query_frame': 517,
#  'object_title': 'microwave',
#  'visual_crop': {'fno': 891,
#   'x': 458.29,
#   'y': 215.52,
#   'w': 579.23,
#   'h': 445.31},
#  'lt_track_valid_range': [425, 1201],
#  'lt_track': [{'fno': 425, 'x': 1643.7, 'y': 402.24, 'w': 276.58, 'h': 680.23},
#   {'fno': 426, 'x': 1253.7, 'y': 259, 'w': 648.34, 'h': 612.36},
#   {'fno': 427, 'x': 1113.54, 'y': 271.53, 'w': 679.22, 'h': 631.64},
#   {'fno': 428, 'x': 990.02, 'y': 336.55, 'w': 733.87, 'h': 681.5},
#   {'fno': 429, 'x': 864, 'y': 292.97, 'w': 818.76, 'h': 717.24},
#   {'fno': 430, 'x': 739.27, 'y': 264.28, 'w': 899.2, 'h': 686.34},
#   {'fno': 431, 'x': 639.72, 'y': 299.59, 'w': 1023.64, 'h': 605.3},
#   {'fno': 432, 'x': 605.69, 'y': 299.46, 'w': 1053.43, 'h': 873.77},
#   {'fno': 433, 'x': 629.96, 'y': 294.31, 'w': 1002.46, 'h': 1007.21},
#   {'fno': 434, 'x': 565.99, 'y': 334.76, 'w': 1036.75, 'h': 1100.92},
#   {'fno': 435, 'x': 469.57, 'y': 390.69, 'w': 1066.17, 'h': 1049.24},
#   {'fno': 436, 'x': 404.34, 'y': 382.19, 'w': 1077.64, 'h': 1057.77},
#   {'fno': 437, 'x': 404.34, 'y': 359.5, 'w': 1086.59, 'h': 1080.52},
#   {'fno': 438, 'x': 418.52, 'y': 373.68, 'w': 1076.27, 'h': 1067.29},
#   {'fno': 439, 'x': 413.14, 'y': 376.78, 'w': 1086.64, 'h': 1063.35},
#   {'fno': 440, 'x': 401.5, 'y': 353.83, 'w': 1102.94, 'h': 1087.16},
#   {'fno': 441, 'x': 452.55, 'y': 345.32, 'w': 1071.67, 'h': 1094.93},
#   {'fno': 442, 'x': 456.95, 'y': 370.84, 'w': 1109.51, 'h': 1070.43},
#   {'fno': 443, 'x': 381.64, 'y': 339.65, 'w': 1333.67, 'h': 1100.92},
#   {'fno': 444, 'x': 390.16, 'y': 325.47, 'w': 1306.96, 'h': 878.84},
#   {'fno': 445, 'x': 381.65, 'y': 336.71, 'w': 1182.55, 'h': 725.93},
#   {'fno': 446, 'x': 356.13, 'y': 348.19, 'w': 1062.2, 'h': 733.91},
#   {'fno': 447, 'x': 333.44, 'y': 331.14, 'w': 1002.12, 'h': 752.63},
#   {'fno': 448, 'x': 297.6, 'y': 406.36, 'w': 986.69, 'h': 765.91},
#   {'fno': 449, 'x': 229.16, 'y': 393.53, 'w': 1016.52, 'h': 788.56},
#   {'fno': 450, 'x': 214.33, 'y': 391.53, 'w': 1025.86, 'h': 797.55},
#   {'fno': 451, 'x': 231.72, 'y': 433.23, 'w': 1009.87, 'h': 791.77},
#   {'fno': 452, 'x': 222.59, 'y': 422.42, 'w': 1029.08, 'h': 791.45},
#   {'fno': 453, 'x': 242.69, 'y': 403.76, 'w': 1052.35, 'h': 796.11},
#   {'fno': 454, 'x': 262.54, 'y': 374.75, 'w': 1091.43, 'h': 780.43},
#   {'fno': 455, 'x': 288.06, 'y': 368.01, 'w': 1114.73, 'h': 776.56},
#   {'fno': 456, 'x': 293.74, 'y': 365.17, 'w': 1142.14, 'h': 779.2},
#   {'fno': 457, 'x': 273.88, 'y': 350.99, 'w': 1168.41, 'h': 785.95},
#   {'fno': 458, 'x': 251.2, 'y': 339.65, 'w': 1186.53, 'h': 785.34},
#   {'fno': 459, 'x': 251.2, 'y': 302.78, 'w': 1148.71, 'h': 783.78},
#   {'fno': 460, 'x': 343.27, 'y': 310.33, 'w': 1029.91, 'h': 741.14},
#   {'fno': 461, 'x': 466.73, 'y': 297.11, 'w': 927.36, 'h': 694.81},
#   {'fno': 462, 'x': 707.58, 'y': 303.58, 'w': 865.95, 'h': 621.65},
#   {'fno': 463, 'x': 1171.2, 'y': 369.45, 'w': 749.32, 'h': 755.53},
#   {'fno': 464, 'x': 1750.54, 'y': 1077.41, 'w': 169.73, 'h': 362.79},
#   {'fno': 486, 'x': 1871.26, 'y': 704.37, 'w': 47.82, 'h': 62.53},
#   {'fno': 487, 'x': 1788.51, 'y': 483.68, 'w': 132.41, 'h': 193.1},
#   {'fno': 488, 'x': 1805.06, 'y': 483.68, 'w': 115.86, 'h': 161.84},
#   {'fno': 489, 'x': 1895.17, 'y': 601.38, 'w': 25.75, 'h': 42.3},
#   {'fno': 518, 'x': 1843.68, 'y': 204.14, 'w': 77.24, 'h': 119.54},
#   {'fno': 519, 'x': 1702.07, 'y': 1.84, 'w': 217.01, 'h': 239.08},
#   {'fno': 520, 'x': 1635.86, 'y': 0, 'w': 283.22, 'h': 196.78},
#   {'fno': 521, 'x': 1540.23, 'y': 1.84, 'w': 288.74, 'h': 114.02},
#   {'fno': 522, 'x': 1345.29, 'y': 0, 'w': 286.9, 'h': 11.03},
#   {'fno': 534, 'x': 1703.91, 'y': 1.84, 'w': 215.17, 'h': 165.52},
#   {'fno': 582, 'x': 1799.72, 'y': 228.97, 'w': 116.97, 'h': 183.17},
#   {'fno': 583, 'x': 1737.01, 'y': 82.76, 'w': 182.07, 'h': 314.48},
#   {'fno': 584, 'x': 1779.31, 'y': 141.61, 'w': 141.61, 'h': 251.95},
#   {'fno': 585, 'x': 1779.31, 'y': 163.68, 'w': 141.61, 'h': 239.08},
#   {'fno': 586, 'x': 1737.01, 'y': 57.01, 'w': 182.07, 'h': 329.2},
#   {'fno': 587, 'x': 1737.01, 'y': 1.84, 'w': 182.07, 'h': 338.39},
#   {'fno': 588, 'x': 1663.45, 'y': 0, 'w': 255.63, 'h': 334.71},
#   {'fno': 589, 'x': 1630.34, 'y': 0, 'w': 288.74, 'h': 332.87},
#   {'fno': 590, 'x': 1591.72, 'y': 0, 'w': 327.36, 'h': 316.32},
#   {'fno': 591, 'x': 1257.01, 'y': -1.84, 'w': 369.66, 'h': 329.2},
#   {'fno': 592, 'x': 445.98, 'y': 1.84, 'w': 689.66, 'h': 529.66},
#   {'fno': 593, 'x': -2.76, 'y': 123.22, 'w': 597.7, 'h': 763.22},
#   {'fno': 594, 'x': -0.92, 'y': 680.46, 'w': 99.31, 'h': 373.33},
#   {'fno': 850, 'x': 1691.03, 'y': 380.69, 'w': 228.05, 'h': 564.6},
#   {'fno': 851, 'x': 1531.03, 'y': 377.01, 'w': 388.05, 'h': 608.74},
#   {'fno': 852, 'x': 1611.95, 'y': 393.56, 'w': 307.13, 'h': 708.05},
#   {'fno': 853, 'x': 1784.83, 'y': 586.67, 'w': 134.25, 'h': 527.82},
#   {'fno': 854, 'x': 1880.46, 'y': 836.78, 'w': 40.46, 'h': 183.91},
#   {'fno': 889, 'x': 1387.59, 'y': 154.48, 'w': 529.66, 'h': 568.28},
#   {'fno': 890, 'x': 800.92, 'y': 145.29, 'w': 588.51, 'h': 467.13},
#   {'fno': 891, 'x': 460.69, 'y': 205.98, 'w': 577.47, 'h': 457.93},
#   {'fno': 892, 'x': 192.18, 'y': 266.67, 'w': 595.86, 'h': 483.68},
#   {'fno': 893, 'x': 52.41, 'y': 308.97, 'w': 599.54, 'h': 502.07},
#   {'fno': 894, 'x': 0.92, 'y': 360.46, 'w': 546.21, 'h': 514.94},
#   {'fno': 895, 'x': 0.92, 'y': 448.74, 'w': 430.34, 'h': 538.85},
#   {'fno': 896, 'x': 0.92, 'y': 509.43, 'w': 290.57, 'h': 579.31},
#   {'fno': 897, 'x': 0.92, 'y': 584.83, 'w': 207.82, 'h': 610.57},
#   {'fno': 898, 'x': 0.92, 'y': 621.61, 'w': 169.2, 'h': 595.86},
#   {'fno': 899, 'x': 0.92, 'y': 588.51, 'w': 193.1, 'h': 560.92},
#   {'fno': 900, 'x': 0.92, 'y': 514.94, 'w': 246.44, 'h': 520.46},
#   {'fno': 901, 'x': 0.92, 'y': 492.87, 'w': 281.38, 'h': 487.36},
#   {'fno': 902, 'x': 0.92, 'y': 428.51, 'w': 349.43, 'h': 468.97},
#   {'fno': 903, 'x': 0.92, 'y': 364.14, 'w': 480, 'h': 446.9},
#   {'fno': 904, 'x': 142.53, 'y': 307.13, 'w': 527.82, 'h': 419.31},
#   {'fno': 905, 'x': 479.08, 'y': 229.89, 'w': 524.14, 'h': 400.92},
#   {'fno': 906, 'x': 962.76, 'y': 204.14, 'w': 538.85, 'h': 413.79},
#   {'fno': 907, 'x': 1450.11, 'y': 275.86, 'w': 470.8, 'h': 516.78},
#   {'fno': 908, 'x': 1867.59, 'y': 724.6, 'w': 51.49, 'h': 209.66},
#   {'fno': 1146, 'x': 116.32, 'y': 296.25, 'w': 334.99, 'h': 442.91},
#   {'fno': 1147, 'x': -0.15, 'y': 386.67, 'w': 304.98, 'h': 488.89},
#   {'fno': 1148, 'x': -0.15, 'y': 426.67, 'w': 253.03, 'h': 533.33},
#   {'fno': 1149, 'x': -0.15, 'y': 465.29, 'w': 183.14, 'h': 616.09},
#   {'fno': 1150, 'x': -0.92, 'y': 941.61, 'w': 27.59, 'h': 101.15},
#   {'fno': 1169, 'x': 1484.14, 'y': 348.14, 'w': 432.55, 'h': 721.66},
#   {'fno': 1170, 'x': 1190.62, 'y': 253.24, 'w': 717.24, 'h': 688.55},
#   {'fno': 1171, 'x': 908.14, 'y': 255.45, 'w': 776.83, 'h': 675.31},
#   {'fno': 1172, 'x': 652.14, 'y': 240, 'w': 922.48, 'h': 697.38},
#   {'fno': 1173, 'x': 466.76, 'y': 262.07, 'w': 1132.14, 'h': 867.31},
#   {'fno': 1174, 'x': 464.55, 'y': 264.28, 'w': 1114.48, 'h': 1039.45},
#   {'fno': 1175, 'x': 552.83, 'y': 279.72, 'w': 1039.45, 'h': 1101.24},
#   {'fno': 1176, 'x': 585.93, 'y': 255.45, 'w': 1037.24, 'h': 1134.34},
#   {'fno': 1177, 'x': 638.9, 'y': 281.93, 'w': 1030.62, 'h': 1143.17},
#   {'fno': 1178, 'x': 875.03, 'y': 284.14, 'w': 1043.86, 'h': 1156.41},
#   {'fno': 1179, 'x': 1265.66, 'y': 500.41, 'w': 653.24, 'h': 940.14},
#   {'fno': 1180, 'x': 1643.03, 'y': 1065.38, 'w': 275.86, 'h': 375.17},
#   {'fno': 1188, 'x': 1601.1, 'y': 476.14, 'w': 317.79, 'h': 701.79},
#   {'fno': 1189, 'x': 1150.9, 'y': 275.31, 'w': 768, 'h': 1008.55},
#   {'fno': 1190, 'x': 713.93, 'y': 240, 'w': 1041.66, 'h': 955.59},
#   {'fno': 1191, 'x': 510.9, 'y': 281.93, 'w': 1083.59, 'h': 1158.62},
#   {'fno': 1192, 'x': 455.72, 'y': 290.76, 'w': 1163.03, 'h': 1149.79},
#   {'fno': 1193, 'x': 502.07, 'y': 268.69, 'w': 1156.41, 'h': 1171.86},
#   {'fno': 1194, 'x': 548.41, 'y': 275.31, 'w': 1127.72, 'h': 1165.24},
#   {'fno': 1195, 'x': 510.9, 'y': 270.9, 'w': 1127.72, 'h': 1169.66},
#   {'fno': 1196, 'x': 508.69, 'y': 242.21, 'w': 1112.28, 'h': 1198.34},
#   {'fno': 1197, 'x': 517.52, 'y': 237.79, 'w': 1068.14, 'h': 1202.76},
#   {'fno': 1198, 'x': 429.24, 'y': 226.76, 'w': 1193.93, 'h': 1213.79},
#   {'fno': 1199, 'x': 265.93, 'y': 220.14, 'w': 1154.21, 'h': 1220.41},
#   {'fno': 1200, 'x': 14.34, 'y': 244.41, 'w': 993.1, 'h': 1176.28},
#   {'fno': 1201, 'x': -1.1, 'y': 513.66, 'w': 476.69, 'h': 929.1}]}

# %%
from PIL import Image
from decord import VideoReader

p_clips_dir = Path('/data/datasets/ego4d_data/v2/clips')
p_crop_out_dir = Path('/data/soyeonhong/vq2d/vq2d-lightning/outputs/lt_tracks') / split

for aidx, ann in enumerate(tqdm(all_anns)):
    clip_uid = ann['clip_uid']
    qset_uuid = f"{ann['annotation_uid']}_{ann['query_set']}"
    rt = ann['lt_track']
    ow, oh = ann['original_width'], ann['original_height']
    frame_idxs = [f['fno'] for f in rt]

    p_obj_dir = p_crop_out_dir / clip_uid
    p_obj_dir.mkdir(exist_ok=True, parents=True)

    p_clip = p_clips_dir / f'{clip_uid}.mp4'
    vr = VideoReader(str(p_clip))
    
    for idx, frame_idx in enumerate(frame_idxs):
        p_out = p_obj_dir / f'{clip_uid}_{frame_idx}_{qset_uuid}.jpg'
        
        if p_out.exists():
            continue
        
        frame = vr[min(6*frame_idx, len(vr)-1)].asnumpy()
        w, h = frame.shape[1], frame.shape[0]
        x1, y1, x2, y2 = rt[idx]['x'] / ow * w, rt[idx]['y'] / oh * h, (rt[idx]['x'] + rt[idx]['w']) / ow * w, (rt[idx]['y'] + rt[idx]['h']) / oh * h
        
        img = Image.fromarray(frame)
        
        if x2 - x1 == 0 or y2 - y1 == 0:
            print(f"Empty crop: {p_out}")
            cropped = img
        else:
            cropped = img.crop((x1, y1, x2, y2))
        
        cropped.save(p_out)
        if aidx % 500 == 0:
            display(cropped)
